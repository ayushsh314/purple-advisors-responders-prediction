# %%
url = f'https://docs.google.com/spreadsheets/d/1vKAIohc1IYOc6E3Y2YLRzAgLcwswKrSKLXX2J47rhjE/gviz/tq?tqx=out:csv&sheet=Updated_Data_Sheet'
import pandas as pd

df=pd.read_csv(url)
df = df[:207]
df.tail()
# Out:
#      LinkedInMemberId FirstName  LastName       Title              Company  \
# 202          52726478   Matthew    Rhodes  Co-Founder          Jarmany Ltd
# 203          50972274    Caspar   Thykier  Co-Founder               Zappar
# 204          50748387   Pramesh      Jain     Founder  WebMob Technologies
# 205          50683480      Nick  Halliday         CEO            IDS Group
# 206          52385801      Mike   Hanauer     CRO/CSO              Redstor
#
#                                             Occupation  \
# 202                           CEO& Co-Founder, JARMANY
# 203                          Co-Founder & CEOat Zappar
# 204        Let’s talk Tech , Growth, Ideas, Solutions!
# 205  CEOof software development & systems integrato...
# 206  Growing GTM teams and creating enterprise valu...
#
#                            Email         Phone Location(original)  \
# 202                          NaN           NaN     United Kingdom
# 203                          NaN           NaN     United Kingdom
# 204                          NaN           NaN      United States
# 205                          NaN           NaN     United Kingdom
# 206  hanauermichael424@gmail.com  7.576720e+09      United States
#
#           Location  ...                       Status ConnectedAt Date  \
# 202    West Europe  ...  MEMBER_INVITATION_WITHDRAWN              NaN
# 203    West Europe  ...  MEMBER_INVITATION_WITHDRAWN              NaN
# 204  North America  ...  MEMBER_INVITATION_WITHDRAWN              NaN
# 205    West Europe  ...  MEMBER_INVITATION_WITHDRAWN              NaN
# 206  North America  ...             MEMBER_CONNECTED           5/7/23
#
#     ConnectedAt Time Number of employees  Name(of classifier)  \
# 202              NaN                71.0                  NaN
# 203              NaN                71.0                  NaN
# 204              NaN                99.0                  NaN
# 205              NaN                29.0                  NaN
# 206       6:33:31 PM               167.0                  NaN
#
#     Industry Classification    Revenue  Revenue(Revised)  Pankaj Comments  \
# 202                 Service  9940000.0         9940000.0              NaN
# 203                 Service  9940000.0         9940000.0              NaN
# 204                 Product        NaN         4900500.0              NaN
# 205                 Service  4060000.0         4060000.0              NaN
# 206                 Product        NaN         8350000.0        8350000.0
#
#                                    Company Description
# 202   helps businesses transform the way they manag...
# 203  provide world-class AR consultancy services to...
# 204                                                NaN
# 205   agile software development and systems integr...
# 206                              Cloud software vendor
#
# [5 rows x 21 columns]

# %%
data = pd.DataFrame()
columns_to_copy = ['Title', 'Location', 'Number of employees', 'Industry Classification', 'Revenue(Revised)', 'Status']

for col in columns_to_copy:
    data[col] = df[col]

# %%
data.head()
# Out:
#   Title       Location  Number of employees Industry Classification  \
# 0   CEO  North America                 28.0                 Product
# 1   CEO           Asia                 17.0                 Service
# 2   CEO    East Europe                137.0                 Service
# 3   CEO    West Europe                111.0                 Service
# 4   CEO    West Europe                 69.0                 Service
#
#    Revenue(Revised)                       Status
# 0          420000.0  MEMBER_INVITATION_WITHDRAWN
# 1         1122000.0             MEMBER_CONNECTED
# 2        12330000.0             MEMBER_CONNECTED
# 3        15540000.0  MEMBER_INVITATION_WITHDRAWN
# 4         9660000.0  MEMBER_INVITATION_WITHDRAWN

# %%
data.tail()
# Out:
#           Title       Location  Number of employees Industry Classification  \
# 202  Co-Founder    West Europe                 71.0                 Service
# 203  Co-Founder    West Europe                 71.0                 Service
# 204     Founder  North America                 99.0                 Product
# 205         CEO    West Europe                 29.0                 Service
# 206     CRO/CSO  North America                167.0                 Product
#
#      Revenue(Revised)                       Status
# 202         9940000.0  MEMBER_INVITATION_WITHDRAWN
# 203         9940000.0  MEMBER_INVITATION_WITHDRAWN
# 204         4900500.0  MEMBER_INVITATION_WITHDRAWN
# 205         4060000.0  MEMBER_INVITATION_WITHDRAWN
# 206         8350000.0             MEMBER_CONNECTED
